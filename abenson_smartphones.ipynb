# %% [markdown]
# ## Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %% [markdown]
# ## HTTP Request

# %% [markdown]
# ### Store website in variable

# %%
website = 'https://www.abenson.com/mobile/smartphone.html'

# %% [markdown]
# ### Get Request

# %%
response = requests.get(website)

# %% [markdown]
# ### Status Code

# %%
response.status_code
# Out:
# 200

# %% [markdown]
# ## Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# ## Result

# %%
results = soup.find_all('div', {'class':'product-item-info product-item-info-custom clearfix'})

# %%
len(results)
# Out:
# 24

# %%
results[0]
# Out:
# <div class="product-item-info product-item-info-custom clearfix" data-container="product-grid">
# <div class="image-wrapper use-promo-badge">
# <a class="product photo product-item-photo" href="https://www.abenson.com/apple-iphone-11-128gb-purple-2020.html" tabindex="-1">
# <span class="product-image-container" style="width:150px;">
# <span class="product-image-wrapper" style="padding-bottom: 100%;">
# <img alt="Apple iPhone 11 128GB Purple Smartphone" class="product-image-photo" height="" src="https://d1rlzxa98cyc61.cloudfront.net/catalog/product/cache/2de03cad1789ed6d6bbbd7ce042d97af/1/7/173386_2020.jpg" width=""/></span>
# </span>
# </a>
# <img class="promo-badge-image" src="https://d1rlzxa98cyc61.cloudfront.net/wysiwyg/promo_badge_url/online-6.6.-deals.png"/> </div>
# <span class="badge-brand"><img src="https://d1rlzxa98cyc61.cloudfront.net/ves/brand/Apple_thumbnail1.png"/></span>
# <div class="sale-wrap"><span class="sale-icon"></span></div> <div class="product details product-item-details">
# <h4 class="product name product-item-name">
# <a class="product-item-link" href="https://www.abenson.com/apple-iphone-11-128gb-purple-2020.html">
#                                         Apple iPhone 11                                    </a>
# </h4>
# <div class="product-item-inner">
# <div class="product description product-item-description">
# <p>128GB Purple</p> <!--a href="https://www.abenson.com/apple-iphone-11-128gb-purple-2020.html" title="Apple iPhone 11"
#                                                class="action more">Learn More</a-->
# </div>
# </div>
# <div class="price-box price-final_price" data-price-box="product-id-13084" data-product-id="13084" data-role="priceBox">
# <span class="special-price">
# <span class="price-wrapper" data-price-amount="32990" data-price-type="finalPrice" product-price-13084"="">
# <span class="price">₱32,990</span> </span>
# </span>
#
# <span class="old-price">
# <span class="price-wrapper" data-price-amount="34990" data-price-type="oldPrice" old-price-13084"="">
# <span class="price">₱34,990</span> </span>
# </span>
#
# <span class="price-box-discount">
#         6%    </span>
# <span class="abenson-monthly_price ab-fs-11"><br/>₱2,915.83/mo</span></div> </div>
# </div>

# %% [markdown]
# ## Target necessary data

# %%
# Product Name
# Price
# Specification
# Installment Price
# Product Link
# Availability

# %% [markdown]
# ### Product Name

# %%
results[0].find('a', {'class':'product-item-link'}).text.strip()
# Out:
# 'Apple iPhone 11'

# %% [markdown]
# ### Price

# %%
results[0].find('span', {'class':'price'}).text
# Out:
# '₱32,990'

# %% [markdown]
# ### Specification

# %%
results[0].find('div', {'class':'product description product-item-description'}).text.strip()
# Out:
# '128GB Purple'

# %% [markdown]
# ### Installment Price

# %%
results[0].find('span', {'class':'abenson-monthly_price ab-fs-11'}).text
# Out:
# '₱2,915.83/mo'

# %% [markdown]
# ### Product Link

# %%
results[0].find('a', {'class':'product-item-link'}).get('href')
# Out:
# 'https://www.abenson.com/apple-iphone-11-128gb-purple-2020.html'

# %% [markdown]
# ### Availability

# %%
try:
    results[0].find('div', {'class':'outofstock'}).text
except:
    results[0] = 'Available'
    
results[0]
# Out:
# 'Available'

# %% [markdown]
# ## Collecting all products inside a For-Loop

# %%
product_name = []
product_price = []
specification = []
installment_price = []
product_link = []
availability = []

for result in results:
    
    # Product Name
    try:
        product_name.append(result.find('a', {'class':'product-item-link'}).text.strip())
    except:
        product_name.append('n/a')
        
    # Product Price
    try:
        product_price.append(result.find('span', {'class':'price'}).text.replace('₱', ''))
    except:
        product_price.append('n/a')
        
    # Specification
    try:
        specification.append(result.find('div', {'class':'product description product-item-description'}).text.strip())
    except:
        specification.append('n/a')
        
    # Installment Price
    try:
        installment_price.append(result.find('span', {'class':'abenson-monthly_price ab-fs-11'}).text.replace('/mo',''))
    except:
        installment_price.append('n/a')
        
    # Product Link
    try:
        product_link.append(result.find('a', {'class':'product-item-link'}).get('href'))
    except:
        product_link.append('n/a')
        
    # Availability
    try:
        availability.append(result.find('div', {'class':'outofstock'}).text)
    except:
        availability.append('Available')

# %%
product_name
# Out:
# ['Apple iPhone 11',
#  'Apple iPhone 11',
#  'Apple iPhone 11',
#  'Samsung Galaxy S22 Ultra (12GB + 256GB) Phantom White',
#  'Samsung Galaxy S22 Ultra (12GB + 256GB) Green',
#  'Samsung Galaxy S22 Ultra (12GB + 256GB) Phantom Black',
#  'Samsung Galaxy S22 Ultra (12GB + 256GB) Burgundy',
#  'Xiaomi Redmi 10C (4GB + 128GB) Graphite Gray',
#  'Xiaomi Redmi 10C (4GB + 64GB) Ocean Blue',
#  'Xiaomi Redmi Note 11 Pro 5G Graphite Gray',
#  'Xiaomi Redmi Note 11 Pro 5G Atlantic Blue',
#  'Xiaomi Redmi Note 11S Graphite Gray',
#  'Xiaomi Redmi Note 11S Twilight Blue',
#  'Vivo Y21T Midnight Blue',
#  'Apple iPhone 13 Pro Max',
#  'Apple iPhone 13 Pro Max',
#  'Apple iPhone 13 Pro Max',
#  'Apple iPhone 13 Pro',
#  'Apple iPhone 13 Pro',
#  'Apple iPhone 13 Pro',
#  'Apple iPhone 13 Pro',
#  'Apple iPhone 13 (PRODUCT)RED',
#  'Apple iPhone 13',
#  'Apple iPhone 13',
#  'Apple iPhone 13',
#  'Apple iPhone 13',
#  'Apple iPhone 13',
#  'Samsung Galaxy M53 5G Brown',
#  'Samsung Galaxy M53 5G Green',
#  'Samsung Galaxy M53 5G Blue',
#  'realme 9i Prism Blue',
#  'OPPO A96 Starry Black',
#  'Xiaomi 12 Pro Gray',
#  'Xiaomi 12 Pro Blue',
#  'Xiaomi 12 Purple',
#  'Xiaomi 12 Gray',
#  'Xiaomi 12 Blue',
#  'Samsung Galaxy A73 5G (8GB + 256GB) Mint',
#  'Samsung Galaxy A73 5G (8GB + 256GB) White',
#  'Samsung Galaxy A73 5G (8GB + 256GB) Gray',
#  'Samsung Galaxy A73 5G (8GB + 128GB) Mint',
#  'Samsung Galaxy A73 5G (8GB + 128GB) Gray',
#  'Apple iPhone SE (3rd Gen)',
#  'Apple iPhone SE (3rd Gen)',
#  'Apple iPhone SE (PRODUCT)RED (3rd Gen)',
#  'Tecno Pop 5 LTE Ice Blue',
#  'Tecno Pop 5 LTE Deepsea Luster',
#  'Apple iPhone SE (3rd Gen)',
#  'Apple iPhone SE (3rd Gen)',
#  'Apple iPhone SE (PRODUCT)RED (3rd Gen)',
#  'Apple iPhone SE (3rd Gen)',
#  'Apple iPhone SE (3rd Gen)',
#  'Apple iPhone 13 Pro Max',
#  'Apple iPhone 13 Pro Max',
#  'Apple iPhone 13',
#  'Samsung Galaxy A23 LTE Awesome Blue',
#  'Samsung Galaxy A23 LTE Awesome White',
#  'Samsung Galaxy A23 LTE Awesome Black',
#  'Samsung Galaxy A33 5G (8GB + 256GB) Awesome Blue',
#  'Samsung Galaxy A33 5G (8GB + 256GB) Awesome Peach',
#  'Samsung Galaxy A33 5G (8GB + 256GB) Awesome White',
#  'Samsung Galaxy A33 5G (8GB + 256GB) Awesome Black',
#  'Apple iPhone 12 (PRODUCT)RED',
#  'Apple iPhone 12',
#  'Apple iPhone 12',
#  'Samsung Galaxy A33 5G (8GB + 128GB) Awesome Blue',
#  'Samsung Galaxy A33 5G (8GB + 128GB) Awesome Peach',
#  'Samsung Galaxy A33 5G (8GB + 128GB) Awesome White',
#  'Samsung Galaxy A33 5G (8GB + 128GB) Awesome Black',
#  'Samsung Galaxy A13 (6GB + 128GB) Awesome Peach',
#  'Samsung Galaxy A13 (6GB + 128GB) Awesome Black',
#  'Samsung Galaxy A13 (6GB + 128GB) Awesome Blue',
#  'Samsung Galaxy A13 (4GB + 128GB) Awesome Peach',
#  'Samsung Galaxy A13 (4GB + 128GB) Awesome Black',
#  'Samsung Galaxy A13 (4GB + 128GB) Awesome Blue',
#  'Vivo Y73 Roman Black',
#  'Samsung Galaxy A53 5G (8GB + 256GB) Blue',
#  'Samsung Galaxy A53 5G (8GB + 256GB) Orange',
#  'Samsung Galaxy A53 5G (8GB + 256GB) White',
#  'Samsung Galaxy A53 5G (8GB + 256GB) Black',
#  'Apple iPhone 13',
#  'Apple iPhone 13',
#  'Apple iPhone 13',
#  'Apple iPhone 13 mini',
#  'Samsung Galaxy S22+ (8GB + 256GB) Phantom Black',
#  'Samsung Galaxy S22+ (8GB + 256GB) Green',
#  'Samsung Galaxy S22+ (8GB + 128GB) Phantom White',
#  'Samsung Galaxy S22+ (8GB + 128GB) Phantom Black',
#  'Samsung Galaxy S22+ (8GB + 128GB) Green',
#  'Samsung Galaxy S22+ (8GB + 128GB) Pink Gold',
#  'Samsung Galaxy A53 5G (8GB + 128GB) Blue',
#  'Samsung Galaxy A53 5G (8GB + 128GB) Orange',
#  'Samsung Galaxy A53 5G (8GB + 128GB) White',
#  'Samsung Galaxy A53 5G (8GB + 128GB) Black',
#  'realme 9 Pro+ 5G (8GB + 256GB) Aurora Green',
#  'Nokia 105 2019 Charcoal Black',
#  'OPPO A16K Black',
#  'OPPO A16K Blue',
#  'Vivo Y01 Sapphire Blue',
#  'Vivo Y01 Elegant Black',
#  'Xiaomi Redmi Note 11 (6GB + 128GB) Graphite Gray',
#  'Apple iPhone 11',
#  'Apple iPhone 11',
#  'Samsung Galaxy S22 Ultra (12GB + 512GB) Burgundy',
#  'Samsung Galaxy S22 Ultra (12GB + 512GB) Phantom Black',
#  'Samsung Galaxy A12 6GB + 128GB Black',
#  'Samsung Galaxy A12 6GB + 128GB Blue',
#  'Apple iPhone 13 Pro Max',
#  'Apple iPhone 13 Pro Max',
#  'Apple iPhone 13 Pro',
#  'Apple iPhone 13 (PRODUCT)RED',
#  'Samsung Galaxy S22 (8GB + 256GB) Phantom White',
#  'Samsung Galaxy S22 (8GB + 256GB) Pink Gold',
#  'Samsung Galaxy S22 (8GB + 128GB) Phantom White',
#  'Samsung Galaxy S22 (8GB + 128GB) Green',
#  'Samsung Galaxy S22 (8GB + 128GB) Pink Gold',
#  'Samsung Galaxy S22 Ultra (12GB + 512GB) Phantom White',
#  'Samsung Galaxy S22 Ultra (12GB + 512GB) Green',
#  'Samsung Galaxy S22 Ultra (8GB + 128GB) Phantom White',
#  'Samsung Galaxy S22+ (8GB + 256GB) Phantom White',
#  'Apple iPhone 13 mini',
#  'realme 9 Pro+ 5G (8GB + 256GB) Sunrise Blue',
#  'realme 9 Pro 5G (8GB + 128GB) Aurora Green',
#  'realme 9 Pro 5G (8GB + 128GB) Sunrise Blue',
#  'Huawei nova 9 SE Midnight Black',
#  'Samsung Galaxy S22+ (8GB + 256GB) Pink Gold',
#  'Vivo V23E 5G Moonlit Shadow',
#  'Samsung Galaxy A03 (4GB + 128GB) Blue',
#  'Samsung Galaxy A03 (4GB + 64GB) Black',
#  'Samsung Galaxy A03 (4GB + 64GB) Blue',
#  'Samsung Galaxy A03 (3GB + 32GB) Black',
#  'Samsung Galaxy A03 (3GB + 32GB) Red',
#  'Samsung Galaxy S21 FE 5G (8GB + 256GB) Graphite',
#  'Samsung Galaxy S21 FE 5G (8GB + 128GB) White',
#  'realme C25Y (4GB + 64GB) Metal Grey',
#  'realme C25Y (4GB + 64GB) Glacier Blue',
#  'Vivo Y76 5G (8GB + 128GB) Midnight Space',
#  'Oppo A95 Glowing Starry Black',
#  'Vivo Y15A (4GB + 64GB) Wave Green',
#  'Vivo Y15A (4GB + 64GB) Mystic Blue',
#  'Vivo Y15S (3GB + 32GB) Mystic Blue',
#  'OPPO A55 (4GB + 64GB) Starry Black',
#  'Xiaomi 11T (8GB + 256GB) Meteorite Gray',
#  'Samsung Galaxy Z Fold3 5G (12GB + 256GB) Phantom Silver',
#  'Samsung Galaxy Z Fold3 5G (12GB + 512GB) Phantom Black',
#  'Oppo A16 (4GB + 64GB) Pearl Blue',
#  'OPPO Reno6 Z 5G Aurora Green',
#  'OPPO Reno6 Z 5G Stellar Black',
#  'OPPO Reno6 5G Stellar Black',
#  'Samsung Galaxy A22 LTE Black',
#  'Vivo V21 5G Dusk Blue',
#  'Apple iPhone 12',
#  'realme 8 (8GB + 128GB) Cyber Silver',
#  'realme 8 (8GB + 128GB) Cyber Black',
#  'realme C11 2021 (2GB + 32GB) Iron Grey',
#  'realme C11 2021 (2GB + 32GB) Lake Blue',
#  'Samsung Galaxy A72 Awesome Black',
#  'Samsung Galaxy S21+ 5G 128GB Phantom Black',
#  'OPPO A15s Mystery Blue',
#  'Samsung Galaxy S21+ 5G 256GB Phantom Silver',
#  'OPPO Reno7 Z 5G Cosmic Black',
#  'Panasonic KX TG6811 CX5',
#  'Panasonic KX TG2711CX5',
#  'Apple iPhone 13 (PRODUCT)RED',
#  'Apple iPhone 11 (PRODUCT) RED',
#  'Apple iPhone 11 Pro Max',
#  'Apple iPhone 11 Pro',
#  'Samsung Galaxy S22 Ultra (8GB + 128GB) Phantom Black',
#  'Apple iPhone 13 Pro Max',
#  'Apple iPhone 13 Pro Max',
#  'Apple iPhone 13 Pro Max',
#  'Apple iPhone 13 Pro Max',
#  'Samsung Galaxy S21 FE 5G (8GB + 256GB) Olive',
#  'Vivo V23E 5G Sunshine Coast',
#  'Vivo Y76 5G (8GB + 128GB) Cosmic Aura',
#  'Samsung Galaxy Z Fold3 5G (12GB + 512GB) Phantom Green',
#  'Apple iPhone 13 Pro',
#  'Apple iPhone 13 mini',
#  'Apple iPhone 13 mini',
#  'Apple iPhone 13 mini',
#  'Apple iPhone 12 mini',
#  'Apple iPhone 12',
#  'Samsung Galaxy M52 5G (8GB + 128GB) Blue',
#  'OPPO Reno2 F Sky White',
#  'Apple iPhone 13',
#  'realme XT Pearl White',
#  'OPPO F11 Marble Green',
#  'Huawei Mate30 Pro Black',
#  'Huawei nova 7 Midsummer Purple',
#  'OPPO F11 Pro Green',
#  'OPPO Reno6 5G Aurora Green',
#  'OPPO Reno 10x Zoom Ocean Green',
#  'Apple iPhone 12 (PRODUCT)RED',
#  'Apple iPhone 12',
#  'OPPO Reno2 F Lake Green',
#  'Apple iPhone 13',
#  'Samsung Galaxy M52 5G (8GB + 128GB) Black',
#  'Huawei nova 7i Crush Green',
#  'Apple iPhone 13',
#  'Apple iPhone 12 Pro',
#  'OPPO F11 Fluorite Purple',
#  'Apple iPhone 12 Pro',
#  'Apple iPhone 13 Pro Max',
#  'Huawei Nova 8i Moonlight Silver',
#  'Samsung Galaxy A72 Awesome Blue',
#  'OPPO A9 2020 Marine Green',
#  'OPPO A5 2020 Dazzling White',
#  'Xiaomi Redmi Note 11 (6GB + 128GB) Twilight Blue',
#  'Apple iPhone 12 mini',
#  'Samsung Galaxy A03s (4GB + 64GB) Black',
#  'Vivo Y20S G Purist Blue',
#  'OPPO A92 Shining White',
#  'Vivo V21 5G Sunset Dazzle',
#  'Huawei Nova 8i Starry Black',
#  'OPPO A5 2020 Mirror Black',
#  'Vivo Y33s (8GB + 128GB) Mirror Black',
#  'realme 8i (6GB + 128GB) Space Black',
#  'Apple iPhone 12',
#  'Apple iPhone 12',
#  'realme 8 5G (8GB + 128GB) Supersonic Blue',
#  'Apple iPhone 11 Pro',
#  'realme 5 Pro 4GB+128GB Crystal Green']

# %% [markdown]
# ## Create Pandas DataFrame

# %%
product_overview = pd.DataFrame({'Name':product_name, 'Price': product_price, 'Specification': specification, 
                                 'Installment Price': installment_price, 'Product Link': product_link})

# %%
product_overview
# Out:
#                                                  Name   Price  \
# 0                                                 n/a     n/a
# 1                                     Apple iPhone 11  32,990
# 2                                     Apple iPhone 11  32,990
# 3   Samsung Galaxy S22 Ultra (12GB + 256GB) Phanto...  72,990
# 4       Samsung Galaxy S22 Ultra (12GB + 256GB) Green  72,990
# 5   Samsung Galaxy S22 Ultra (12GB + 256GB) Phanto...  72,990
# 6    Samsung Galaxy S22 Ultra (12GB + 256GB) Burgundy  72,990
# 7        Xiaomi Redmi 10C (4GB + 128GB) Graphite Gray   7,299
# 8            Xiaomi Redmi 10C (4GB + 64GB) Ocean Blue   6,299
# 9           Xiaomi Redmi Note 11 Pro 5G Graphite Gray  15,999
# 10          Xiaomi Redmi Note 11 Pro 5G Atlantic Blue  15,999
# 11                Xiaomi Redmi Note 11S Graphite Gray  12,999
# 12                Xiaomi Redmi Note 11S Twilight Blue  12,999
# 13                            Vivo Y21T Midnight Blue  10,999
# 14                            Apple iPhone 13 Pro Max  76,990
# 15                            Apple iPhone 13 Pro Max  70,990
# 16                            Apple iPhone 13 Pro Max  70,990
# 17                                Apple iPhone 13 Pro  82,990
# 18                                Apple iPhone 13 Pro  82,990
# 19                                Apple iPhone 13 Pro  70,990
# 20                                Apple iPhone 13 Pro  70,990
# 21                       Apple iPhone 13 (PRODUCT)RED  67,990
# 22                                    Apple iPhone 13  54,990
# 23                                    Apple iPhone 13  54,990
#
#                                         Specification Installment Price  \
# 0                                                 n/a               n/a
# 1                                         128GB White         ₱2,915.83
# 2                                         128GB Black         ₱2,915.83
# 3   6.8-inch Quad HD+, Snapdragon 895, 256GB, 5000mAh         ₱6,082.50
# 4   6.8-inch Quad HD+, Snapdragon 895, 256GB, 5000mAh         ₱6,082.50
# 5   6.8-inch Quad HD+, Snapdragon 895, 256GB, 5000mAh         ₱6,082.50
# 6   6.8-inch Quad HD+, Snapdragon 895, 256GB, 5000mAh         ₱6,082.50
# 7               6.71-inch HD+, SD 680, 128GB, 5000mAh           ₱708.25
# 8                6.71-inch HD+, SD 680, 64GB, 5000mAh           ₱583.25
# 9          6.67-inch Full HD+, SD 695, 128GB, 5000mAh         ₱1,333.25
# 10         6.67-inch Full HD+, SD 695, 128GB, 5000mAh         ₱1,333.25
# 11        6.43-inch Full HD+, MTK G96, 128GB, 5000mAh         ₱1,083.25
# 12        6.43-inch Full HD+, MTK G96, 128GB, 5000mAh         ₱1,083.25
# 13              6.51-inch HD+, SD 680, 128GB, 5000mAh         ₱1,041.58
# 14                                  256GB Sierra Blue         ₱6,582.50
# 15                                         128GB Gold         ₱6,082.50
# 16                                     128GB Graphite         ₱6,082.50
# 17                                         512GB Gold         ₱7,082.50
# 18                                     512GB Graphite         ₱7,082.50
# 19                                  256GB Sierra Blue         ₱6,082.50
# 20                                     256GB Graphite         ₱6,082.50
# 21                                          512GB Red         ₱5,915.83
# 22                                         256GB Blue         ₱4,915.83
# 23                                         256GB Pink         ₱4,915.83
#
#                                          Product Link
# 0                                                 n/a
# 1   https://www.abenson.com/apple-iphone-11-128gb-...
# 2   https://www.abenson.com/apple-iphone-11-128gb-...
# 3   https://www.abenson.com/samsung-galaxy-s22-ult...
# 4   https://www.abenson.com/samsung-galaxy-s22-ult...
# 5   https://www.abenson.com/samsung-galaxy-s22-ult...
# 6   https://www.abenson.com/samsung-galaxy-s22-ult...
# 7   https://www.abenson.com/xiaomi-redmi-10c-4gb-1...
# 8   https://www.abenson.com/xiaomi-redmi-10c-4gb-6...
# 9   https://www.abenson.com/xiaomi-redmi-note-11-p...
# 10  https://www.abenson.com/xiaomi-redmi-note-11-p...
# 11  https://www.abenson.com/xiaomi-redmi-note-11s-...
# 12  https://www.abenson.com/xiaomi-redmi-note-11s-...
# 13  https://www.abenson.com/vivo-y21t-midnight-blu...
# 14  https://www.abenson.com/apple-iphone-13-pro-ma...
# 15  https://www.abenson.com/apple-iphone-13-pro-ma...
# 16  https://www.abenson.com/apple-iphone-13-pro-ma...
# 17  https://www.abenson.com/apple-iphone-13-pro-51...
# 18  https://www.abenson.com/apple-iphone-13-pro-51...
# 19  https://www.abenson.com/apple-iphone-13-pro-25...
# 20  https://www.abenson.com/apple-iphone-13-pro-25...
# 21  https://www.abenson.com/apple-iphone-13-produc...
# 22  https://www.abenson.com/apple-iphone-13-256gb-...
# 23  https://www.abenson.com/apple-iphone-13-256gb-...

# %% [markdown]
# ## Scrape 19 pages (Pagination)

# %%
product_name = []
product_price = []
specification = []
installment_price = []
product_link = []
availability = []

# Collect products from page 1-19
for i in range(1,20):
    
    # Store website in variable
    website = 'https://www.abenson.com/mobile/smartphone/page/' + str(i) + '.html'

    # Get Request
    response = requests.get(website)
    
    # Soup Object
    soup = BeautifulSoup(response.content, 'html.parser')
    
    # Result
    results = soup.find_all('div', {'class':'product-item-info product-item-info-custom clearfix'})

    # Collecting all products of multiple pages inside a For-Loop 
    for result in results:

        # Product Name
        try:
            product_name.append(result.find('a', {'class':'product-item-link'}).text.strip())
        except:
            product_name.append('n/a')

        # Product Price
        try:
            product_price.append(result.find('span', {'class':'price'}).text.replace('₱', ''))
        except:
            product_price.append('n/a')

        # Specification
        try:
            specification.append(result.find('div', {'class':'product description product-item-description'}).text.strip())
        except:
            specification.append('n/a')

        # Installment Price
        try:
            installment_price.append(result.find('span', {'class':'abenson-monthly_price ab-fs-11'}).text.replace('₱',''))
        except:
            installment_price.append('n/a')

        # Product Link
        try:
            product_link.append(result.find('a', {'class':'product-item-link'}).get('href'))
        except:
            product_link.append('n/a')

# %%
product_overview = pd.DataFrame({'Name':product_name, 'Price': product_price, 'Specification': specification, 
                                 'Installment Monthly Payment': installment_price, 'Product Link': product_link})

# %%
product_overview
# Out:
#                                                   Name   Price  \
# 0                                      Apple iPhone 11  32,990
# 1                                      Apple iPhone 11  32,990
# 2                                      Apple iPhone 11  32,990
# 3    Samsung Galaxy S22 Ultra (12GB + 256GB) Phanto...  72,990
# 4        Samsung Galaxy S22 Ultra (12GB + 256GB) Green  72,990
# ..                                                 ...     ...
# 217                                    Apple iPhone 12  44,990
# 218                                    Apple iPhone 12  53,990
# 219          realme 8 5G (8GB + 128GB) Supersonic Blue  12,490
# 220                                Apple iPhone 11 Pro  58,990
# 221               realme 5 Pro 4GB+128GB Crystal Green  11,498
#
#                                          Specification  \
# 0                                         128GB Purple
# 1                                          128GB White
# 2                                          128GB Black
# 3    6.8-inch Quad HD+, Snapdragon 895, 256GB, 5000mAh
# 4    6.8-inch Quad HD+, Snapdragon 895, 256GB, 5000mAh
# ..                                                 ...
# 217                                         128GB Blue
# 218                                        256GB Black
# 219  6.5-inch HD+, MTK Dimensity 700 5G, 128GB, 500...
# 220                                    64GB Space Gray
# 221                       6.3-inch, Octa-Core, 4035mAh
#
#     Installment Monthly Payment  \
# 0                   2,915.83/mo
# 1                   2,915.83/mo
# 2                   2,915.83/mo
# 3                   6,082.50/mo
# 4                   6,082.50/mo
# ..                          ...
# 217                 3,915.83/mo
# 218                 4,665.83/mo
# 219                 1,040.83/mo
# 220                 4,915.83/mo
# 221                 1,083.17/mo
#
#                                           Product Link
# 0    https://www.abenson.com/apple-iphone-11-128gb-...
# 1    https://www.abenson.com/apple-iphone-11-128gb-...
# 2    https://www.abenson.com/apple-iphone-11-128gb-...
# 3    https://www.abenson.com/samsung-galaxy-s22-ult...
# 4    https://www.abenson.com/samsung-galaxy-s22-ult...
# ..                                                 ...
# 217  https://www.abenson.com/apple-iphone-12-128gb-...
# 218  https://www.abenson.com/apple-iphone-12-256gb-...
# 219  https://www.abenson.com/realme-8-5g-8gb-128gb-...
# 220  https://www.abenson.com/apple-iphone-11-pro-64...
# 221  https://www.abenson.com/realme-5-pro-4gb-plus-...
#
# [222 rows x 5 columns]

# %% [markdown]
# ## Cleaning the Price and Installment Monthly Payment

# %%
# Prepare data for Visualization
product_overview['Price'] = product_overview['Price'].str.replace(',', '')
product_overview['Installment Monthly Payment'] = product_overview['Installment Monthly Payment'].str.replace(',', '')
product_overview['Installment Monthly Payment'] = product_overview['Installment Monthly Payment'].str.replace('/mo', '')

product_overview
# Out:
#                                                   Name  Price  \
# 0                                      Apple iPhone 11  32990
# 1                                      Apple iPhone 11  32990
# 2                                      Apple iPhone 11  32990
# 3    Samsung Galaxy S22 Ultra (12GB + 256GB) Phanto...  72990
# 4        Samsung Galaxy S22 Ultra (12GB + 256GB) Green  72990
# ..                                                 ...    ...
# 217                                    Apple iPhone 12  44990
# 218                                    Apple iPhone 12  53990
# 219          realme 8 5G (8GB + 128GB) Supersonic Blue  12490
# 220                                Apple iPhone 11 Pro  58990
# 221               realme 5 Pro 4GB+128GB Crystal Green  11498
#
#                                          Specification  \
# 0                                         128GB Purple
# 1                                          128GB White
# 2                                          128GB Black
# 3    6.8-inch Quad HD+, Snapdragon 895, 256GB, 5000mAh
# 4    6.8-inch Quad HD+, Snapdragon 895, 256GB, 5000mAh
# ..                                                 ...
# 217                                         128GB Blue
# 218                                        256GB Black
# 219  6.5-inch HD+, MTK Dimensity 700 5G, 128GB, 500...
# 220                                    64GB Space Gray
# 221                       6.3-inch, Octa-Core, 4035mAh
#
#     Installment Monthly Payment  \
# 0                       2915.83
# 1                       2915.83
# 2                       2915.83
# 3                       6082.50
# 4                       6082.50
# ..                          ...
# 217                     3915.83
# 218                     4665.83
# 219                     1040.83
# 220                     4915.83
# 221                     1083.17
#
#                                           Product Link
# 0    https://www.abenson.com/apple-iphone-11-128gb-...
# 1    https://www.abenson.com/apple-iphone-11-128gb-...
# 2    https://www.abenson.com/apple-iphone-11-128gb-...
# 3    https://www.abenson.com/samsung-galaxy-s22-ult...
# 4    https://www.abenson.com/samsung-galaxy-s22-ult...
# ..                                                 ...
# 217  https://www.abenson.com/apple-iphone-12-128gb-...
# 218  https://www.abenson.com/apple-iphone-12-256gb-...
# 219  https://www.abenson.com/realme-8-5g-8gb-128gb-...
# 220  https://www.abenson.com/apple-iphone-11-pro-64...
# 221  https://www.abenson.com/realme-5-pro-4gb-plus-...
#
# [222 rows x 5 columns]

# %% [markdown]
# ## Create Excel file using DataFrame

# %%
# Saving to excel file for Visualization
product_overview.to_excel('abenson_smartphones.xlsx', index=False)
